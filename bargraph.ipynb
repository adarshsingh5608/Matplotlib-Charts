# %%
import matplotlib.pyplot as plt

# %%
x =['mon','tues','wed','thus','fri']
y= [10,15,7,20,25]
plt.bar(x,y)
plt.xlabel('days')
plt.ylabel('sales')
plt.title('sales according to week days')
plt.show()
