# %%
import matplotlib.pyplot as plt

# %%
hours= [1,2,3,4,5,6]
scores =[45,56,76,87,65,54]
plt.scatter(hours , scores , color= 'green' ,marker='o')
plt.xlabel('Hours Studied')
plt.ylabel('Marks get')
plt.tit
plt.show()
