# %%
import matplotlib.pyplot as plt

# %%
region =['North','South','East','West']
revenue =[5000,4000,7000,6000]
plt.pie(revenue ,labels =region , autopct='%1.1f%%' ,colors =['grey','lightgreen','lightblue','coral'])
plt.title('Revenue Collection by Regions')
plt.show()
