# %%
import matplotlib.pyplot as plt

# %%
scores =[45,56,76,87,65,54,64,86,97,74,73,49,52,58,86]
plt.hist(scores , bins =5,color ='yellow' , edgecolor='white')
plt.xlabel('Score Range')
plt.ylabel('Number of Student')
plt.title('Score of Students')
plt.show()
